# %%
import pandas as pd

# %%
df_validation = pd.read_csv('final_data/data_validation.csv')

# %%
df_validation
# Out:
#      AGE  PTEDUCAT       FDG     AV45  CDRSB  ADAS11  ADAS13  ADASQ4  MMSE  \
# 0   73.7        14  1.264620  0.97060    2.0    8.00   13.00     4.0  30.0
# 1   70.3        12  1.293390  1.20829    0.0    5.33    7.33     2.0  25.0
# 2   76.6        18  1.178970  1.20829    1.5   14.67   23.67     9.0  25.0
# 3   82.5        14  1.275480  1.00230    1.0    6.00    8.00     1.0  28.0
# 4   68.6        17  1.150180  1.02910    2.0   12.00   18.00     6.0  26.0
# 5   86.8        16  1.133460  0.94690    1.0    3.33    5.33     2.0  29.0
# 6   69.2        18  1.179760  1.53770    3.5   22.00   33.00    10.0  21.0
# 7   81.8        15  1.165720  1.05500    0.5    9.00   10.00     1.0  29.0
# 8   83.2        19  1.098800  1.56300    4.5   23.00   33.00     9.0  26.0
# 9   69.4        12  1.050340  1.20829    3.5   23.00   34.00    10.0  25.0
# 10  67.8        12  1.198979  1.05690    0.0    7.33    7.33     0.0  29.0
# ...

# %%
df_validation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 37 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   AGE                    15 non-null     float64
#  1   PTEDUCAT               15 non-null     int64
#  2   FDG                    15 non-null     float64
#  3   AV45                   15 non-null     float64
#  4   CDRSB                  15 non-null     float64
#  5   ADAS11                 15 non-null     float64
#  6   ADAS13                 15 non-null     float64
#  7   ADASQ4                 15 non-null     float64
#  8   MMSE                   15 non-null     float64
#  9   RAVLT_immediate        15 non-null     float64
#  10  RAVLT_perc_forgetting  15 non-null     float64
#  11  LDELTOTAL              15 non-null     float64
#  12  TRABSCOR               15 non-null     float64
#  13  FAQ                    15 non-null     float64
# ...

# %%
df_validation['DX_bl'].value_counts()
# Out:
# DX_bl
# EMCI    3
# CN      3
# LMCI    3
# AD      3
# SMC     3
# Name: count, dtype: int64

# %%
for key, value in df_validation.items():
    print(f'{key}: {value[0]}')
# Out:
# AGE: 73.7
# PTEDUCAT: 14
# FDG: 1.26462
# AV45: 0.9706
# CDRSB: 2.0
# ADAS11: 8.0
# ADAS13: 13.0
# ADASQ4: 4.0
# MMSE: 30.0
# RAVLT_immediate: 31.0
# RAVLT_perc_forgetting: 50.0
# LDELTOTAL: 9.0
# TRABSCOR: 82.0
# FAQ: 0.0
# MOCA: 25.0
# EcogPtMem: 2.0
# EcogPtLang: 1.33333
# EcogPtVisspat: 1.14286
# EcogPtDivatt: 2.0
# EcogPtTotal: 1.53846
# EcogSPMem: 1.125
# EcogSPLang: 1.33333
# EcogSPVisspat: 1.14286
# EcogSPPlan: 1.2
# EcogSPOrgan: 1.0
# EcogSPDivatt: 1.75
# EcogSPTotal: 1.23077
# FSVERSION: Cross-Sectional FreeSurfer (5.1)
# Hippocampus: 7616.0
# Entorhinal: 3631.965770171149
# ICV: 1523040.0
# mPACCdigit: -1.54144
# mPACCtrailsB: -1.372
# FAQTOTAL: 3.7049689440993774
# ADNI_MEM: 0.3656816226183159
# PTGENDER: Male
# DX_bl: EMCI

# %%
{
  "AGE": 73.7,
  "PTEDUCAT": 14,
  "FDG": 1.26462,
  "AV45": 0.9706,
  "CDRSB": 2.0,
  "ADAS11": 8.0,
  "ADAS13": 13.0,
  "ADASQ4": 4.0,
  "MMSE": 30.0,
  "RAVLT_immediate": 31.0,
  "RAVLT_perc_forgetting": 50.0,
  "LDELTOTAL": 9.0,
  "TRABSCOR": 82.0,
  "FAQ": 0.0,
  "MOCA": 25.0,
  "EcogPtMem": 2.0,
  "EcogPtLang": 1.33333,
  "EcogPtVisspat": 1.14286,     
  "EcogPtDivatt": 2.0,
  "EcogPtTotal": 1.53846,
  "EcogSPMem": 1.125,
  "EcogSPLang": 1.33333,
  "EcogSPVisspat": 1.14286,
  "EcogSPPlan": 1.2,
  "EcogSPOrgan": 1.0,
  "EcogSPDivatt": 1.75,
  "EcogSPTotal": 1.23077,
  "FSVERSION": "Cross-Sectional FreeSurfer (5.1)",
  "Hippocampus": 7616.0,
  "Entorhinal": 3631.965770171149,
  "ICV": 1523040.0,
  "mPACCdigit": -1.54144,
  "mPACCtrailsB": -1.372,
  "FAQTOTAL": 3.7049689440993774,
  "ADNI_MEM": 0.3656816226183159,
  "PTGENDER": "Male"
}   


"DX_bl,": EMCI
# Out:
#   Cell In[64], line 2
#     "AGE": 81.8
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
{
  "AGE": 0,

# %%
df_validation['FLDSTRENG']
# Out:
# 0       3 Tesla MRI
# 1     1.5 Tesla MRI
# 2     1.5 Tesla MRI
# 3       3 Tesla MRI
# 4       3 Tesla MRI
# 5               NaN
# 6       3 Tesla MRI
# 7               NaN
# 8       3 Tesla MRI
# 9     1.5 Tesla MRI
# 10              NaN
# 11    1.5 Tesla MRI
# 12              NaN
# 13              NaN
# 14              NaN
# Name: FLDSTRENG, dtype: object
